# %% [markdown]
# ## Lab 2 การเตรียมข้อมูล `2-Stemming`
# จงอธิบายวิธีการทำงานของ Porter Stemmer แต่ละขั้นตอนสำหรับการหารากคำของคำต่อไปนี้โดยให้ระบุว่าในแต่ละขั้นตอนเข้ากฎไหนและเมื่อผ่านขั้นตอนดังกล่าวแล้วจะได้คำดังตาราง

# %% [markdown]
# ![image_wk2.png](attachment:image_wk2.png)

# %% [markdown]
# ## `programmers`
#
# Step 1A :
#
# ers -> s : programmer
#
# Step 4 : The suffixes are now removed.
#
# er -> er : programm
#
# `Ans -> programm`
#
# ## `programming`
#
# Step 1b:
#
# programming -> ing : programm
#
# (m>0) programm -> mm : program
#
# `Ans -> program`
#
#
# ## `because`
#
#
# (m=1 and not *o) E ->  because -> becaus
#
# `Ans -> becaus`
